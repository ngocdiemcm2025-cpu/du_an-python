# %%
import pandas as pd 
import numpy as np 
df=pd.read_excel(r'c:\Users\PC\Downloads\sales_boss_assignment.xlsx')
print(df.shape)
print(df.columns)
print(df.head())
print(df.info())
loc=df.loc[:,['Product','Price']]
print(loc)
a=df.loc[(df['Quantity'] > 7 )]
print(a)
b=df.loc[(df['Price'] > 100)]
print(b)
c=df.loc[(df['Quantity'] >7) & (df['Price'] <100)]
D=c.loc[:,['Product','Quantity','Price','City']]
trung_binh=np.mean(df['Quantity'])
gia_tri_lon_nhat=np.max(df['Quantity'])
gia_nho_nhat=np.min(df['Quantity'])
tong=np.sum(df['Quantity'])
vi_tri=np.argmax(df['Quantity'])
trung_binh1=np.mean(df['Price'])
vitri=np.argmax(df['Price'])
list=[]
pricelon=df['Price'] > trung_binh1 
price1=df['Price']
price2=price1[pricelon]
list.append(price2)
tinhtiendonhang=df['Price']*df['Quantity']
tongdoanthu=np.sum(tinhtiendonhang)
n=df.loc[(df['Quantity'] > 7)&(df['Price'] <100)]
m=n.loc[:,['Product','Quantity','Price']]
p=np.sum(n['Quantity'])
# Out:
# (10, 5)
# Index(['Product', 'Quantity', 'Price', 'Customer', 'City'], dtype='str')
#     Product  Quantity  Price Customer     City
# 0    Laptop         2   1500       An  Can Tho
# 1     Mouse        10     25     Binh      HCM
# 2  Keyboard         5     50      Chi  Da Nang
# 3   Monitor         3    300     Dung  Can Tho
# 4   Headset         8     80       An      HCM
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   10 non-null     str
#  1   Quantity  10 non-null     int64
#  2   Price     10 non-null     int64
#  3   Customer  10 non-null     str
#  4   City      10 non-null     str
# dtypes: int64(2), str(3)
# memory usage: 532.0 bytes
# None
#     Product  Price
# 0    Laptop   1500
# 1     Mouse     25
# 2  Keyboard     50
# 3   Monitor    300
# 4   Headset     80
# 5    Laptop   1500
# 6     Mouse     25
# 7   Monitor    300
# ...

# %%
# Out:
# 0    3000
# 1     250
# 2     250
# 3     900
# 4     640
# 5    1500
# 6     375
# 7     600
# 8     350
# 9     960
# dtype: int64
